# %%
# The dataset here is about the sales of avocados in multiple US markets(the dataset has been taken from Kaggle)

# %% [markdown]
# Importing the dataset from my github repository

# %%
import urllib.request

# %%
urllib.request.urlretrieve('https://raw.githubusercontent.com/siddharthdhaka/DATA-ANALYSIS-IN-PANDAS/main/avocados.csv','avocados-market.csv')
# Out:
# ('avocados-market.csv', <http.client.HTTPMessage at 0x1aa2132e748>)

# %% [markdown]
# Reading the csv file through pandas that stores it in a dataframe object

# %%
import pandas as pd

# %%
avocados_df = pd.read_csv('avocados-market.csv')

# %%
avocados_df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1               1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2               2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3               3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4               4  11/29/2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7    2/4/2018          1.63      17074.83  2046.96    1529.20
# 18245           8   1/28/2018          1.71      13888.04  1191.70    3431.50
# 18246           9   1/21/2018          1.87      13766.76  1191.92    2452.79
# 18247          10   1/14/2018          1.93      16205.22  1527.63    2981.04
# 18248          11    1/7/2018          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# THE TOTAL VOLUME HERE REPRESENTS TOTAL SALES VOLUME
# THE ATTRIBUTES NAMED AS-
# 4046- REPRESENTS TOTAL SALES VOLUME OF AVOCADOS WITH PLU 4046
# 4225- REPRESENTS TOTAL SALES VOLUME OF AVOCADOS WITH PLU 4225
# 4770- REPRESENTS TOTAL SALES VOLUME OF AVOCADOS WITH PLU 4770 (PLU stands for Price Look-up codes)

# %%
avocados_df.describe
# Out:
# <bound method NDFrame.describe of        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1               1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2               2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3               3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4               4  11/29/2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7    2/4/2018          1.63      17074.83  2046.96    1529.20
# 18245           8   1/28/2018          1.71      13888.04  1191.70    3431.50
# 18246           9   1/21/2018          1.87      13766.76  1191.92    2452.79
# 18247          10   1/14/2018          1.93      16205.22  1527.63    2981.04
# 18248          11    1/7/2018          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# PANDAS TEND TO STORE COLUMN NAMES(ATTRIBUTES) AS KEYS(LIKE IN A DICTIONARY BUT HERE A TABULAR FORMAT PRESENT)

# %%
#ANALYZING TOTAL SALES VOLUME BY REGION

# %%
avocados_df[['Total Volume', 'region']]
# Out:
#        Total Volume            region
# 0          64236.62            Albany
# 1          54876.98            Albany
# 2         118220.22            Albany
# 3          78992.15            Albany
# 4          51039.60            Albany
# ...             ...               ...
# 18244      17074.83  WestTexNewMexico
# 18245      13888.04  WestTexNewMexico
# 18246      13766.76  WestTexNewMexico
# 18247      16205.22  WestTexNewMexico
# 18248      17489.58  WestTexNewMexico
#
# [18249 rows x 2 columns]

# %%
avocados_df.sort_values('Total Volume', ascending = False)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume         4046  \
# 9097            7    2/4/2018          0.87   62505646.52  21620180.90
# 8366           47    2/5/2017          0.77   61034457.10  22743616.17
# 5506           46    2/7/2016          0.76   52288697.89  16573573.78
# 8353           34    5/7/2017          1.09   47293921.60  17076650.82
# 5493           33    5/8/2016          0.82   46324529.70  14223304.98
# ...           ...         ...           ...           ...          ...
# 13193          12   10/2/2016          1.49        472.82        10.50
# 11698          24   7/12/2015          2.05        419.98         0.00
# 13189           8  10/30/2016          1.58        385.55         8.13
# 9437           51    1/4/2015          1.73        379.82         0.00
# 10381           7   11/8/2015          1.59         84.56         3.95
#
#               4225        4770   Total Bags   Small Bags  Large Bags  \
# ...

# %%
#here we see that total US sales are also present, this is the part of the data we don't need now, so I will create a view 
#to drop some of the columns so that original dataframe remains unaffected.

# %%
avocados_df_copy = avocados_df.copy()

# %%
#

# %%
index_us = avocados_df_copy[avocados_df_copy['region'] == 'TotalUS'].index

# %%
# deleting index(s) where column name under attribute region is TotalUS

# %%
avocados_df_copy.drop(index_us, inplace = True)

# %%
# now assessing total sales volume by region

# %%
avocados_df_copy.sort_values('Total Volume', ascending = False)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 8419           47    2/5/2017          0.66   11274749.11  4377537.67
# 5981           47    2/5/2017          0.67   11213596.29  3986429.59
# 8557            7    2/4/2018          0.80   10894677.77  4473811.63
# 9109            7    2/4/2018          0.83   10565056.41  3121272.58
# 3166           46    2/7/2016          0.70   10361698.17  2930343.28
# ...           ...         ...           ...           ...         ...
# 13193          12   10/2/2016          1.49        472.82       10.50
# 11698          24   7/12/2015          2.05        419.98        0.00
# 13189           8  10/30/2016          1.58        385.55        8.13
# 9437           51    1/4/2015          1.73        379.82        0.00
# 10381           7   11/8/2015          1.59         84.56        3.95
#
#              4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %% [markdown]
# IN THE ABOVE TABLE IT CAN BE SEEN THAT MAXIMUM SALES VOLUME IS IN THE WESTERN REGION FOLLOWED BY CALIFORNIA. PREDICTIVELY, IT CAN BE SAID THAT IF AVOCADO SALE IN THESE AREAS IN MAXIMUM, THEN COMPANIES SELLING AVOCADO PRODUCTS WOULD BENEFIIT IF THEY CONCENTRATE THEIR SALES IN THIS REGION.

# %%
#TAKING TOP 10 REGIONS

# %%
avocados_df_copy.sort_values('Total Volume', ascending = False).head(10)
# Out:
#       Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 8419          47   2/5/2017          0.66   11274749.11  4377537.67
# 5981          47   2/5/2017          0.67   11213596.29  3986429.59
# 8557           7   2/4/2018          0.80   10894677.77  4473811.63
# 9109           7   2/4/2018          0.83   10565056.41  3121272.58
# 3166          46   2/7/2016          0.70   10361698.17  2930343.28
# 9025           7   2/4/2018          0.65   10323174.59  4772921.95
# 5558          46   2/7/2016          0.69    9718438.84  3353158.49
# 8048          47   2/5/2017          0.62    9421609.22  5160896.68
# 359           47   2/1/2015          0.85    9032180.67  4794142.14
# 9018           0  3/25/2018          0.70    9010588.32  3999735.71
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 8419  2558039.85  193764.89  4145406.70  2508731.79  1627453.06      9221.85
# ...

# %%
#in the top regions, alongwith west region and california, South Central region also holds maximum avocado market of the US

# %%
#knowing areas with smallest avocado market in the US---

# %%
avocados_df_copy.sort_values('Total Volume', ascending = True).head(20)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume    4046    4225  \
# 10381           7   11/8/2015          1.59         84.56    3.95    3.95
# 9437           51    1/4/2015          1.73        379.82    0.00   59.82
# 13189           8  10/30/2016          1.58        385.55    8.13   47.42
# 11698          24   7/12/2015          2.05        419.98    0.00   63.42
# 13193          12   10/2/2016          1.49        472.82   10.50   18.99
# 11697          23   7/19/2015          2.07        482.26    0.00   75.74
# 16201          29   6/11/2017          2.19        515.01  399.62    5.92
# 9426           40   3/22/2015          1.93        530.96    0.00  147.63
# 13190           9  10/23/2016          1.58        542.85    8.14   81.38
# 11719          45   2/15/2015          1.72        561.10    0.00   47.64
# 12133          44   2/21/2016          1.67        562.64   35.36  425.56
# 12201           8  10/30/2016          1.63        563.06    3.60  126.13
# ...

# %% [markdown]
# IT CAN BE SEEN THAT REGIONS WITH LEAST AVOCADO SALES ARE- MIAMIFTLAUDERDALE, BUFFALOROCHESTER, NEWORLEANS AND SYRACUSE

# %%
#people in these areas of the US tend to consume less avocados compared to others.
#THE SALES VOLUME HAS BEEN ANALYZED OVER A THREE - YEAR PERIOD

# %%
#NOW, PANDAS DOES NOT KNOW THAT DATE COLUMN HAS ITS OWN IMPORTANT MEANING HERE, SO I HAVE TO FIRST CONVERT THIS ATTRIBUTE IN
# ITS FORM

# %%
avocados_df_copy['Date'] = pd.to_datetime(avocados_df_copy.Date)

# %%
avocados_df_copy['year'] = pd.DatetimeIndex(avocados_df_copy.Date).year
avocados_df_copy['month'] = pd.DatetimeIndex(avocados_df_copy.Date).month

# %%
avocados_df_copy
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0               0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 18244           7 2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
#analyzing avocado sales by month oof the year

# %%
bymonth = avocados_df_copy[['Total Volume', 'month']]

# %%
bymonth.sort_values('Total Volume', ascending = True).head(20)
# Out:
#        Total Volume  month
# 10381         84.56     11
# 9437         379.82      1
# 13189        385.55     10
# 11698        419.98      7
# 13193        472.82     10
# 11697        482.26      7
# 16201        515.01      6
# 9426         530.96      3
# 13190        542.85     10
# 11719        561.10      2
# 12133        562.64      2
# 12201        563.06     10
# 12132        566.57      2
# 10396        571.40      7
# 11693        588.87      8
# 11725        593.39      1
# 9410         614.30      7
# 11723        627.80      1
# 16207        634.09      4
# 11687        657.42      9

# %%
# we can see that total sales are independent of the month because avocados are staple foodsource in US for entire year.
#So, this aggregation of data won't help in making any kind of business decision unless more information is provided.

# %%
#looking at data of the year 2017---

# %%
byyear = avocados_df_copy.year == 2017

# %%
latestdata = avocados_df_copy[byyear]

# %%
#checking fluctuation in average price in the year 2017 by analyzing first 30 records

# %%
latestdata[['AveragePrice', 'month', 'Total Volume']].head(30)
# Out:
#       AveragePrice  month  Total Volume
# 5616          1.47     12     113514.42
# 5617          1.45     12      77039.09
# 5618          1.43     12      70677.56
# 5619          1.29     12      92325.53
# 5620          1.39     12     139970.00
# 5621          1.50     11      62977.00
# 5622          1.65     11      97273.00
# 5623          1.26     11     113586.00
# 5624          1.62     11      71076.94
# 5625          1.67     10      69432.23
# 5626          1.56     10      69704.09
# 5627          1.65     10      73574.89
# 5628          1.78     10      55368.61
# 5629          1.69     10      71205.11
# 5630          1.64      9      68539.64
# 5631          1.41      9      80109.29
# 5632          1.78      9      99645.88
# 5633          1.76      9      74297.64
# 5634          1.61      8      75471.56
# 5635          1.61      8      74620.33
# 5636          1.52      8     133070.41
# 5637          1.53      8      92938.17
# ...

# %% [markdown]
# AVERAGE PRICE OOF AVOCADOS IN THE YEAR 2017 DIDN'T SHOW MUCH FLUCTUATION, MOSTLY BECAUSE ITS A STAPLE AND HIGH CONSUMPTION FOOD SOURCE IN THE USA. THE AVERAGE PRICE WAS MOSTLY IN THE RANGE OF 1.5 - 1.7. AT THE SAME TIME, SUDDEN INCREASE IN COST IN FUTURE WOULD NOT AFFECT THE SALES TO A GREAT EXTENT BECAUSE AGAIN FOR THE SAME REASON THAT IT IS A STAPLE FOOD AND CHANCES OF THE LATTER HAPPENING ARE MEAGRE.

# %%
# TOTAL SALES VOLUME OF AVOCADOS WITH PLU 4046

# %%
latestdata['4046'].sum()
# Out:
# 1015660962.5300001

# %%
#TOTAL SALES VOLUME OF AVOCADOS WITH PLU 4225

# %%
latestdata['4225'].sum()
# Out:
# 967700263.64

# %%
#TOTAL SALES VOLUME OF AVOCADOS WITH PLU 4770

# %%
latestdata['4770'].sum()
# Out:
# 57611449.44

# %%
#THE PLU CODES ON FRESH PRODUCE DENOTES OF THE VARIETY/ SIZE. TYPE OF PRODUCE. HERE, WE MAY BE DEALING WITH VARIETY OF AVOCADOS
#AS IT CAN BE SEEN IN ABOVE EXECUTIONS, TOTAL SALES VOLUME OF AVOCADOS WITH PLU 4046 IS MAXIMUM AND WITH PLU 4770 IS LEAST.

# %% [markdown]
# calculating total sales for the years available in the dataset, i.e, 2015- 2018

# %%
#FOR 2015

# %%
byyearfifteen = avocados_df_copy.year == 2015

# %%
forfifteen=avocados_df_copy[byyearfifteen]

# %%
forfifteen['Total Volume'].sum()
# Out:
# 2728213440.62

# %%
#FOR 2016

# %%
byyearsixteen = avocados_df_copy.year == 2016

# %%
forsixteen = avocados_df_copy[byyearsixteen]

# %%
forsixteen['Total Volume'].sum()
# Out:
# 3001730749.0499997

# %%
#FOR 2017

# %%
latestdata['Total Volume'].sum()
# Out:
# 3069612135.8900003

# %%
#FOR 2018

# %%
byyeareighteen = avocados_df_copy.year == 2018

# %%
foreighteen = avocados_df_copy[byyeareighteen]

# %%
foreighteen['Total Volume'].sum()
# Out:
# 859106086.0400001

# %% [markdown]
# AS SEEN FROM THE ABOVE EXECUTIONS, TOTAL SALES OF AVOCADOS ARE INCREASING WITH PASSING YEAR. THE REASON IS THAT FOR AN EVERYDAY USED FOOD PRODUCT, THE DEMAND IS A FUNCTION OF POPULATION, SO NATURALLY DEMAND RISES AND CONSEQUENTLY GROWTH OF THE MARKET IS SEEN.BUT A DRASTIC DROP IN SALES HAS BEEN SEEN IN 2018. THIS MAYBE BECAUSE OF INCREASING TAX ON THE RESOURCES REQUIRED TO PRODUCE AVOCADOS AND OTHER NATURAL CONSTRAINTS LIKE WATER SCARCITY, ETC.THIS CAN ALSO BE DUE TO SUDDEN INCREASE IN PRICE.

# %%
#analyzing total sales through graph by first setting new index as month to get month-wise plot---

# %%
forfifteen.set_index('month', inplace = True)

# %%
forfifteen['Total Volume'].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
#though the graph looks smudged at places, on thw whole we can say that total sales at the start of the year are greater
#compared to following months but on the whole, much variration is not seen in the year 2015.

# %% [markdown]
# CREATING A SEPARATE DATAFRAME CONTAINIG BASIC SALES INFORMATION WITH YEAR FOR AN OVERALL ANALYSIS---

# %%
byyears = [['2015', 2728213440.62],['2016', 3001730749.0499997],['2017', 3069612135.8900003],['2018',859106086.0400001]]

# %%
new_df = pd.DataFrame(byyears, columns = ['year', 'Total Volume'])

# %%
new_df
# Out:
#    year  Total Volume
# 0  2015  2.728213e+09
# 1  2016  3.001731e+09
# 2  2017  3.069612e+09
# 3  2018  8.591061e+08

# %%
new_df.set_index('year', inplace = True)

# %%
new_df['Total Volume'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# THE PROBABLE REASONS FOR THE SHARP DECLINE IN SALES AFTER 2017 HAVE BEEN DICUSSED ABOVE.
